# %%
from __future__ import annotations
from pathlib import Path
import re
import sys
import itertools

INFINITY = sys.maxsize

#input_file = Path(".") / "example1_p1-7_p2-33.txt"
#input_file = Path(".") / "example2_p1-2_p2-9.txt"
#input_file = Path(".") / "example3_p1-3_p2-3.txt"
input_file = Path(".") / "input.txt"

class Indicator:
    def __init__(self, lights_count, lights_state: int):
        '''
        Args:
            lights_count(int): Number of lightbulbs represented by this indicator. For example: 4
            lights_state (int): Represents state of lights in binary string format. For example: four lights, first on, three off: "1000"
        '''
        self._lights_count = lights_count
        self._lights_state = lights_state
    
    def __repr__(self) -> str:
        return f"Indicator<state={format(self._lights_state, '0'+str(self._lights_count)+'b')}>"

    def __eq__(self, other) -> bool:
        return isinstance(other, Indicator) and self._lights_count == other._lights_count and self._lights_state == other._lights_state

    def __hash__(self):
        return hash((self._lights_count, self._lights_state))

    @classmethod
    def create_from_string(cls, lights: str) -> Self:
        '''Create an instance from state string
        Args:
            lights (str): Represents state of lights in binary string format. For example: four lights, first on, three off: "1000"
        '''
        return cls(len(lights), int(lights, 2))

    def create_all_off(self) -> Self:
        '''Create an instance with all lights switched off
        '''
        return Indicator(self.lights_count, 0)

    def switch(self, button: Button) -> Self:
        '''Apply button press to the lights
        Args:
            button (Button): Button compatible with the indicator
        Returns:
            Indicator: New indicator
        '''
        if self.lights_count != button.total_switches_count:
            raise ValueError(f"{button} is not compatible with {self}")

        return Indicator(self.lights_count, button.control_light(self._lights_state))

    @property
    def lights_count(self) -> int:
        return self._lights_count

class JoltageLevels:
    def __init__(self, levels: list):
        '''
        Args:
            levels (list): List of integers representing the joltage levels.
        '''
        self._levels = levels

    def __repr__(self) -> str:
        return f"JoltageLevels<levels={self._levels}>"

    def __eq__(self, other) -> bool:
        return self._levels == other._levels

    def __hash__(self):
        return hash(tuple(self._levels))

    def create_all_zero(self) -> Self:
        '''Create an instance with all levels set to zero'''
        return JoltageLevels([0] * len(self._levels))

    def switch(self, button: Button) -> Self:
        '''Apply button press to the joltage levels
        Args:
            button (Button): Button compatible with the joltage levels
        Returns:
            JoltageLevels: New joltage levels
        '''
        if len(self._levels) != button.total_switches_count:
            raise ValueError(f"{button} is not compatible with {self}")

        levels = button.apply_joltage(self._levels)
      
        return JoltageLevels(levels)

    @property
    def odd_level_positions(self) -> set:
        '''Returns the positions where the level is odd number'''
        diff = set()
        for index in range(len(self._levels)):
            if self._levels[index] % 2 != 0:
                diff.add(index)
        return diff

    @property
    def is_valid(self) -> bool:
        '''Check if the current state is valid
        Valid levels are non-negative integers.
        '''
        for level in self._levels:
            if level < 0:
                return False
        return True

    @property
    def is_halvable(self) -> bool:
        '''True when it makes sense to divide the state by 2
        Examples (for 3 switches):
            4,6,6 -> True
            4,6,1 -> False
            8,0,8 -> True
        '''
        return len(self.odd_level_positions) == 0

    def halve(self) -> Self:
        '''Decrease all levels by half and return a new instance'''
        updated_levels = []
        for level in self._levels:
            updated_levels.append(int(level / 2))
        return JoltageLevels(updated_levels)

    def to_indicator(self) -> Indicator:
        '''Even levels equivalent to lights off, odd levels equivalent to lights on'''
        count = len(self._levels)
        lights_state = 0        
        for index in self.odd_level_positions:
            lights_state += 2 ** (count - index - 1)
        return Indicator(count, lights_state)

class Button:
    def __init__(self, total_switches_count: int, switches: list):
        '''
        Args:
            total_switches_count (int): Total number of switches a button could possibly control.
            switches (list): Indexes of switches that this button controls (starting from zero, moving left to right).
        '''
        if total_switches_count <= 0:
            raise ValueError("Button must control at least one switch")
        if len(switches) == 0:
            raise ValueError("Button must have at least one switch configuration")

        self._total_switches_count = total_switches_count
        self._controller = 0
        self._controlled_positions = set(switches)

        for index in switches:
            if index < 0 or index >= total_switches_count:
                raise ValueError(f"Button cannot control the switch {index}. Valid switches are from 0 to {total_switches_count - 1}")

            self._controller += 2 ** (total_switches_count - index - 1)
    
    def __repr__(self) -> str:
        return f"Button<switches={format(self._controller, '0'+str(self._total_switches_count)+'b')}>"

    def __lt__(self, other) -> bool:
        return len(self._controlled_positions) < len(other._controlled_positions)

    @property
    def total_switches_count(self) -> int:
        return self._total_switches_count

    def control_light(self, state: int) -> int:
        '''Apply the switches of the button to the given state of lights
        Args:
            state (int): State of lights
        Return:
            int: Updated state of lights
        '''
        return state ^ self._controller
    
    def apply_joltage(self, levels: list) -> list:
        '''Apply the given number of button presses to the levels
        Args:
            levels (list): List of integers indicating the joltage levels indexed by position.
        Return:
            list: Updated joltage levels
        '''
        updated_levels = levels.copy()
        count = len(updated_levels)
        
        for index in range(count):
            if 2 ** index & self._controller != 0:
                updated_levels[count - index - 1] -= 1
        
        return updated_levels

def create_indicator(config: str) -> Indicator:
    '''Factory method for Indicator'''
    return Indicator.create_from_string(config.replace('.', '0').replace('#', '1'))

def create_buttons(lights_count: int, config: str) -> list:
    '''Factory method for Button list'''
    buttons = []
    for button_config in config.strip().split(' '):
        light_switches = list(map(int, button_config.strip('()').split(',')))
        buttons.append(Button(lights_count, light_switches))
    return buttons

def create_joltage_levels(config: str) -> JoltageLevels:
    '''Factory method for JoltageLevels'''
    return JoltageLevels(list(map(int, config.strip().split(','))))

def calculate_min_button_presses_for_indicator(start_indicator: Indicator, buttons: list) -> int:
    '''Calculate the minimum number of button presses to go from start to target state
    The target state is the full zero state. So it's counting down.
    Args:
        start_indicator (Indicator): Any non-zero state can be a start state.
        buttons (list): List of all Button objects to use.
    Return:
        int: Minimum number of button presses. When there is no solution then INFINITY is returned.
    '''
    target_indicator = start_indicator.create_all_off()
    min_button_presses = INFINITY
    for button_combinations in calculate_button_combinations_list(start_indicator, target_indicator, buttons):
        min_button_presses = min(min_button_presses, len(button_combinations))
    return min_button_presses

def all_button_combinations(buttons: list):
    '''Generate button combinations without repetition'''
    for i in range(1, len(buttons) + 1):
        for value in itertools.combinations(buttons, i):
            yield value

def calculate_button_combinations_list(start_indicator, target_indicator: Indicator, buttons: list) -> list:
    '''Find button combinations that would result the target indicator'''
    button_combinations_list = []
    for combination in all_button_combinations(buttons):
        state = start_indicator
        for button in combination:
            state = state.switch(button)
        if state == target_indicator:
            button_combinations_list.append(combination)
    return button_combinations_list

def calculate_min_button_presses_for_joltage(start_state: JoltageLevels, buttons: list, cache: dict) -> int:
    '''Calculate the minimum number of button presses to go from start to target state
    The target state is the full zero state. So it's counting down.
    Args:
        start_state (JoltageLevels): Any non-zero levels as start state.
        buttons (list): List of Button objects to use.
        cache (dict): Key-value store for tracking previous recursive computation results.
    Return:
        int: Minimum number of button presses. When there is no solution then INFINITY is returned.
    '''
    cached_result = cache.get(start_state)
    if cached_result != None:
        return cached_result
    if start_state == start_state.create_all_zero():
        return 0

    # Assosiate the target joltage levels to an indicator
    start_indicator = start_state.to_indicator()
    target_indicator = start_indicator.create_all_off()
    button_presses = [INFINITY] # When there is no solution to the current state, then return infinity
    
    # Appying button combinations (each button once at most) to see if we get a halvable state
    for button_combinations in calculate_button_combinations_list(start_indicator, target_indicator, buttons):
        state = start_state
        #print(f"state {start_state}: from {start_indicator} to {target_indicator} by {button_combinations}")
        for button in button_combinations:
            state = state.switch(button)
        if not state.is_valid:
            continue # skip button combinations leading to invalid state
        multiplier = 1
        if state.is_halvable:
            state = state.halve()
            multiplier = 2
        presses = len(button_combinations) + multiplier * calculate_min_button_presses_for_joltage(state, buttons, cache)
        button_presses.append(presses)

    # If the start state is halvable try to solve from there.
    if start_state.is_halvable:
        state = start_state.halve()
        presses = 2 * calculate_min_button_presses_for_joltage(state, buttons, cache)
        button_presses.append(presses)
    
    result = min(button_presses)
    cache[start_state] = result
    #print(f"{start_state} result: {result} = min({button_presses})")
    return result

def calculate_all_for_indicator() -> int:
    '''Process all indicator challenges and sum the results'''
    total = 0
    for index in range(len(target_indicators)):
        total += calculate_min_button_presses_for_indicator(target_indicators[index], buttons[index])
    return total

def calculate_all_for_joltage() -> int:
    '''Process all joltage challenges and sum the results'''
    total = 0
    for index in range(len(target_joltage_levels)):
        total += calculate_min_button_presses_for_joltage(target_joltage_levels[index], buttons[index], dict())
    return total

# Initialize and read input
target_indicators = []
buttons = []
target_joltage_levels = []
with input_file.open(mode="r", encoding="utf-8") as file:
    for line in file:
        matches = re.match(r"\[(.+)\] ([^{}]+) {(.+)}", line)
        indicator_config = matches[1]
        buttons_config = matches[2]
        joltage_config = matches[3]
        indicator = create_indicator(indicator_config)
        target_indicators.append(indicator)
        buttons.append(create_buttons(indicator.lights_count, buttons_config))
        target_joltage_levels.append(create_joltage_levels(joltage_config))

# Process input
print(f"Part1 answer: {calculate_all_for_indicator()}")
print(f"Part2 answer: {calculate_all_for_joltage()}")
# Out:
# Part1 answer: 3
# Part2 answer: 3
